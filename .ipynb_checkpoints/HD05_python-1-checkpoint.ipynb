# %%
# Importa bibliotecas
import numpy as np
import matplotlib.pyplot as plt
from scipy import fftpack

# Parâmetros do sinal
Ac = 2                                                         # Amplitude da portadora
Mu1 = 1                                                        # Índice de modulação
Mu2 = 0.5                                                       # Índice de modulação
Mu3 = 2                                                       # Índice de modulação

fc = 25000                                                     # Frequência da portadora Hz
fm = 2000
N = 1000
Ts = 1e-6                                                      # Tempo de amostragem pequeno (modelar sinal contínuo)
t = np.arange(N)*Ts
s1 = Ac*(1+Mu1*np.cos(2*np.pi*fm*t))*np.cos(2*np.pi*fc*t)
s2 = Ac*(1+Mu2*np.cos(2*np.pi*fm*t))*np.cos(2*np.pi*fc*t)
s3 = Ac*(1+Mu3*np.cos(2*np.pi*fm*t))*np.cos(2*np.pi*fc*t)

# Gráfico do AM-DSB no tempo
plt.figure(1,[10,8])
plt.subplot(311)
plt.plot(t,s1)
plt.title("Sinal AM no tempo - AM-DSB (Índice de modulação = 1)")
plt.xlabel("Tempo [s]")
plt.ylabel("Amplitude")

# Gráfico do AM-DSB no tempo
plt.figure(2,[10,8])
plt.subplot(312)
plt.plot(t,s2)
plt.title("Sinal AM no tempo - AM-DSB (Índice de modulação = 0.5)")
plt.xlabel("Tempo [s]")
plt.ylabel("Amplitude")

# Gráfico do AM-DSB no tempo
plt.figure(3,[10,8])
plt.subplot(313)
plt.plot(t,s3)
plt.title("Sinal AM no tempo - AM-DSB (Índice de modulação = 2)")
plt.xlabel("Tempo [s]")
plt.ylabel("Amplitude")

plt.show()

# Cálculo da FFT de AM-DSB
lfft = 30                                                      # Número pontos da fft
k = np.arange(-lfft,lfft)                                      # Vetor de frequências 
S_f = 2.0*np.abs((fftpack.fft(s)))/N                           # Cálculo da FFT
Ns = len(s)                                                    # Comprimento do sinal modulado
Nk = len(k)                                                    # Comprimento do sinal em frequência

Px_fft = np.sum(S_f*np.conj(S_f))                              # Cálculo da potência na frêquencia
print('Potência via FFT (Parseval) = ',abs(Px_fft))
# Out:
# Potência via FFT (Parseval) =  9.96
